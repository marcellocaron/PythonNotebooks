# %%
import pandas as pd

# %%
df = pd.read_csv("/Users/marcello/Desktop/20200426 - Governo SP - Report Status de Pagamento de Beneficiários - Consolidado.csv.csv")

# %%
df.head(10)
# Out:
#      cd_aluno                 nm_aluno           cpf       nome_responsavel  \
# 0  24949460.0       BRIDA SANTOS SOUZA  4.283435e+10  LEDIANI SANTOS DA PAZ
# 1  26024752.0       BRYAN SANTOS SOUZA  4.283435e+10  LEDIANI SANTOS DA PAZ
# 2  27123360.0         YAN SANTOS SOUZA  4.283435e+10  LEDIANI SANTOS DA PAZ
# 3  28345345.0      BRENDA SANTOS SOUZA  4.283435e+10  LEDIANI SANTOS DA PAZ
# 4  28919887.0        RYAN SANTOS SOUZA  4.283435e+10  LEDIANI SANTOS DA PAZ
# 5  30480575.0  JOAO PEDRO SANTOS SOUZA  4.283435e+10  LEDIANI SANTOS DA PAZ
# 6  33130337.0        SETH SANTOS SOUZA  4.283435e+10  LEDIANI SANTOS DA PAZ
# 7  33873065.0   ANA LUISA SANTOS SOUZA  4.283435e+10  LEDIANI SANTOS DA PAZ
# 8         NaN                      NaN  4.283435e+10  LEDIANI SANTOS DA PAZ
# 9         NaN                      NaN  4.283435e+10  LEDIANI SANTOS DA PAZ
#
#            flag_ordem  quantidade_de_beneficios comp_direito_vs_pagto  \
# ...

# %%
df.query('quantidade_de_beneficios == 8.0').count()
# Out:
# cd_aluno                        48
# nm_aluno                        48
# cpf                             63
# nome_responsavel                63
# flag_ordem                      63
# quantidade_de_beneficios        63
# comp_direito_vs_pagto           63
# data_pagamento                  55
# consumer_id                     63
# cod_pagamento_primeira_ordem    40
# cod_pagamento_segunda_ordem     15
# Conta_Criada                    63
# PAGO                            63
# status_cadastro                 63
# data_status_cadastro            63
# order_benef                     48
# order_pay                       55
# dtype: int64

# %%
df.dtypes()

pd.Da
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-0dd702c13f05> in <module>
# ----> 1 df.datatypes()
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'datatypes'
