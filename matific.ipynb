# %%
import pandas as pd

# %%
path = 'data/MATIFIC_ALUNO_v3.csv'

# %%
df = pd.read_csv(path, sep=';', error_bad_lines=False)
# Out:
# b'Skipping line 146848: expected 17 fields, saw 22\n'
# b'Skipping line 417490: expected 17 fields, saw 18\n'
# b'Skipping line 910285: expected 17 fields, saw 18\n'

# %%
df.head()
# Out:
#    CD_ALUNO                        NM_ALUNO           NR_RG NR_DIG_RG  \
# 0  10565146             LINDAURA DOS SANTOS  00000055871928         4
# 1   8977470         GENALDO CARVALHO JATOBÁ  00000052869217         3
# 2   3523719              CRISTIANA DA SILVA  00000546198478       NaN
# 3  15209788  EDVANIA MARIA DOS SANTOS SILVA  00000062372872         2
# 4  16019487       JOSE FABIO SOUSA TEIXEIRA  00000001493586       NaN
#
#   SG_UF_RG        NR_CPF NM_EMAIL  CD_TURMA  COD_ESCOLA   CD_INEP  \
# 0       SE  2.558082e+10      NaN  36906754      911069  35911069
# 1       SP  6.504585e+09      NaN  36689149       38830  35038830
# 2       AL  9.411199e+10      NaN  36639849      909543  35909543
# 3       SP  1.813040e+10      NaN  36842086      908472  35908472
# 4       SE  9.828938e+10      NaN  36842073      908472  35908472
#
#    COD_DIRETORIA  NM_USUARIO             NR_RA             LOGIN EMAIL_MS  \
# ...

# %%
df[df.COD_ESCOLA == 23059].head()
# Out:
#        CD_ALUNO                           NM_ALUNO NR_RG NR_DIG_RG SG_UF_RG  \
# 4663   23941224            CARLOS EDUARDO DE PAULA   NaN       NaN      NaN
# 18524  25423593              TALES DANILO DE SOUSA   NaN       NaN      NaN
# 19808  25477398               ISABELI SANTOS SOUZA   NaN       NaN      NaN
# 19817  25477512  ISABELA EDUARDA SOUTO DE OLIVEIRA   NaN       NaN      NaN
# 19820  25477659    ADRIANO DE PAULA MESSIAS CINTRA   NaN       NaN      NaN
#
#        NR_CPF NM_EMAIL  CD_TURMA  COD_ESCOLA   CD_INEP  COD_DIRETORIA  \
# 4663      NaN      NaN  36618334       23059  35023059          20504
# 18524     NaN      NaN  36618334       23059  35023059          20504
# 19808     NaN      NaN  36618334       23059  35023059          20504
# 19817     NaN      NaN  36618333       23059  35023059          20504
# 19820     NaN      NaN  36618334       23059  35023059          20504
#
#        NM_USUARIO             NR_RA             LOGIN  \
# ...
