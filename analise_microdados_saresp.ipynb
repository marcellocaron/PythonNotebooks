# %%
import pandas as pd

# %%
df = pd.read_csv('data/MICRODADOS_SARESP_2019.csv', sep=',') #, error_bad_lines=False)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# /Users/marcello/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (13,37) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#    CD_ALUNO      NOMEDEP     NomeDepBol                RegiaoMetropolitana  \
# 0     54425  ESTADUAL-SE  Rede Estadual                           Interior
# 1    199609  ESTADUAL-SE  Rede Estadual                           Interior
# 2    338808  ESTADUAL-SE  Rede Estadual  Região Metropolitana de São Paulo
# 3   1743905  ESTADUAL-SE  Rede Estadual                           Interior
# 4   1746017  ESTADUAL-SE  Rede Estadual                           Interior
#
#    CDREDE               DE  CODMUN                 MUN  CODESC  TIPOCLASSE  \
# 0   20803          BIRIGUI     753             LOURDES   30193           0
# 1   20313          ITARARE     365             ITABERA   39718           0
# 2   10317            SUL 1     100           SAO PAULO   41750           0
# 3   20908  SANTO ANASTACIO     240               CAIUA  904211           0
# 4   20801        ANDRADINA     480  NOVA INDEPENDENCIA   29324           0
#
# ...

# %%
df.shape
# Out:
# (970744, 38)

# %%
df2 = pd.read_csv('data/new_MICRODADOS_SARESP_2019.csv', sep=';') #, error_bad_lines=False)
# Out:
# /Users/marcello/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df2.head()
# Out:
#    CD_ALUNO      NOMEDEP     NomeDepBol RegiaoMetropolitana  CDREDE  \
# 0     54425  ESTADUAL-SE  Rede Estadual            Interior   20803
# 1    199609  ESTADUAL-SE  Rede Estadual            Interior   20313
# 2    190846  ESTADUAL-SE  Rede Estadual            Interior   20305
# 3    317226  ESTADUAL-SE  Rede Estadual            Interior   20301
# 4    318858  ESTADUAL-SE  Rede Estadual            Interior   20702
#
#               DE  CODMUN              MUN  CODESC  TIPOCLASSE  ...  \
# 0        BIRIGUI     753          LOURDES   30193           0  ...
# 1        ITARARE     365          ITABERA   39718           0  ...
# 2        ITAPEVA     756     NOVA CAMPINA  915117           0  ...
# 3          APIAI     737  BARRA DO CHAPEU   14412           0  ...
# 4  FERNANDOPOLIS     444        MERIDIANO   27005           0  ...
#
#   TOTAL_PONTO_MAT porc_ACERT_lp  porc_ACERT_mat profic_lp profic_mat  \
# 0               0             0               0       NaN        NaN
# ...

# %%
df2.shape
# Out:
# (1050917, 38)
