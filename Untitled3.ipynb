# %%
import numpy as np
import matplotlib.pyplot as plt

plt.rcParams.update({'font.size': 20})

x = np.linspace(0, 2, 100)

plt.figure(figsize=(20,8))
plt.plot(x, x, label='linear')  # Plot some data on the axes.
plt.plot(x, x**2, label='quadratic')  
plt.plot(x, x**3, label='cubic')
plt.xlabel('x label', fontsize=30)
plt.ylabel('y label', fontsize=30)
plt.title("pyplot style", fontsize=30)
plt.xticks(np.arange(0,2.5,0.5))
plt.yticks(np.arange(0,10,2))
plt.grid(ls='--', lw=1)
plt.legend()
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-30-23d3a4189120> in <module>
# ----> 1 x.query('x > 2')
#
# AttributeError: 'numpy.ndarray' object has no attribute 'query'
